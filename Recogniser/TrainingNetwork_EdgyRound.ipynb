# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import pickle
import numpy as np
import tensorflowjs as tfjs
from keras.callbacks import EarlyStopping

#Load training data
X = pickle.load(open("XEdgyRound.pickle", "rb"))
Y = pickle.load(open("YEdgyRound.pickle", "rb"))

#normalize input values (pixel values range from 0 - 255)
X = np.array(X/255.0)
Y = np.array(Y)

#Load validation data
ValidX = pickle.load(open("XEdgyRoundValid.pickle", "rb"))
ValidY = pickle.load(open("YEdgyRoundValid.pickle", "rb"))

#normalize input values (pixel values range from 0 - 255)
ValidX = np.array(ValidX/255.0)
ValidY = np.array(ValidY)


#Build the architecture of the network:

model = Sequential()
model.add(Conv2D(32, (3,3), padding="same", input_shape = X.shape[1:]))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Conv2D(64, (3,3), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Conv2D(128, (3,3), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size = (2,2)))


model.add(Conv2D(256, (3,3), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size = (2,2)))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(256))
model.add(Dropout(0.5))


model.add(Dense(2))
model.add(Activation("softmax"))

#Use Adam optimizer and, if desired, specify learning rate:
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)
optimizer = tf.keras.optimizers.Adam()

#Select loss function:
model.compile(loss = "binary_crossentropy", 
              optimizer = optimizer,
              metrics = ['accuracy'])

#stop early if loss does not further decrease after a specified number of epochs (patience):
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=8)

#print a summary of model:
model.summary()

#train model with specified batch size for a maximum specified number of epochs
model.fit(X, Y, batch_size = 64, epochs = 50, validation_data = (ValidX, ValidY), callbacks = [es])

#save the model:
model.save('MODELNAME')

#convert model to a format that is readable by tensorflow.js to use it in the word generator:
tfjs.converters.save_keras_model(model, "SAVE PATH")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 100, 100, 32)      320
# _________________________________________________________________
# activation_10 (Activation)   (None, 100, 100, 32)      0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 50, 50, 64)        18496
# _________________________________________________________________
# activation_11 (Activation)   (None, 50, 50, 64)        0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 25, 25, 128)       73856
# _________________________________________________________________
# activation_12 (Activation)   (None, 25, 25, 128)       0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 12, 12, 256)       295168
# _________________________________________________________________
# activation_13 (Activation)   (None, 12, 12, 256)       0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 6, 6, 256)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 9216)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               2359552
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 514
# _________________________________________________________________
# activation_14 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 2,747,906
# Trainable params: 2,747,906
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 175/175 [==============================] - 5s 25ms/step - loss: 0.6176 - accuracy: 0.6245 - val_loss: 0.3761 - val_accuracy: 0.8651
# Epoch 2/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.2238 - accuracy: 0.9150 - val_loss: 0.1772 - val_accuracy: 0.9418
# Epoch 3/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.1301 - accuracy: 0.9523 - val_loss: 0.0988 - val_accuracy: 0.9677
# Epoch 4/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0858 - accuracy: 0.9680 - val_loss: 0.0796 - val_accuracy: 0.9693
# Epoch 5/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0551 - accuracy: 0.9804 - val_loss: 0.0515 - val_accuracy: 0.9806
# Epoch 6/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0422 - accuracy: 0.9838 - val_loss: 0.0674 - val_accuracy: 0.9774
# Epoch 7/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0365 - accuracy: 0.9874 - val_loss: 0.0431 - val_accuracy: 0.9847
# Epoch 8/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0490 - accuracy: 0.9814 - val_loss: 0.0603 - val_accuracy: 0.9790
# Epoch 9/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0258 - accuracy: 0.9899 - val_loss: 0.0443 - val_accuracy: 0.9855
# Epoch 10/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0174 - accuracy: 0.9927 - val_loss: 0.0369 - val_accuracy: 0.9871
# Epoch 11/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0106 - accuracy: 0.9954 - val_loss: 0.0367 - val_accuracy: 0.9879
# Epoch 12/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0149 - accuracy: 0.9941 - val_loss: 0.0304 - val_accuracy: 0.9895
# Epoch 13/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0115 - accuracy: 0.9954 - val_loss: 0.0493 - val_accuracy: 0.9814
# Epoch 14/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0145 - accuracy: 0.9943 - val_loss: 0.0336 - val_accuracy: 0.9830
# Epoch 15/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0142 - accuracy: 0.9946 - val_loss: 0.0450 - val_accuracy: 0.9871
# Epoch 16/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0120 - accuracy: 0.9956 - val_loss: 0.0375 - val_accuracy: 0.9911
# Epoch 17/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0076 - accuracy: 0.9963 - val_loss: 0.0582 - val_accuracy: 0.9895
# Epoch 18/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0155 - accuracy: 0.9931 - val_loss: 0.0403 - val_accuracy: 0.9871
# Epoch 19/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0128 - accuracy: 0.9946 - val_loss: 0.0727 - val_accuracy: 0.9766
# Epoch 20/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0133 - accuracy: 0.9950 - val_loss: 0.0269 - val_accuracy: 0.9911
# Epoch 21/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0063 - accuracy: 0.9974 - val_loss: 0.0274 - val_accuracy: 0.9927
# Epoch 22/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0094 - accuracy: 0.9961 - val_loss: 0.0355 - val_accuracy: 0.9871
# Epoch 23/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0045 - accuracy: 0.9979 - val_loss: 0.0357 - val_accuracy: 0.9911
# Epoch 24/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0103 - accuracy: 0.9964 - val_loss: 0.0410 - val_accuracy: 0.9855
# Epoch 25/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0115 - accuracy: 0.9963 - val_loss: 0.0136 - val_accuracy: 0.9919
# Epoch 26/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0068 - accuracy: 0.9967 - val_loss: 0.0251 - val_accuracy: 0.9887
# Epoch 27/50
# 175/175 [==============================] - 4s 25ms/step - loss: 0.0069 - accuracy: 0.9975 - val_loss: 0.0374 - val_accuracy: 0.9871
# Epoch 28/50
# 175/175 [==============================] - 4s 25ms/step - loss: 0.0087 - accuracy: 0.9964 - val_loss: 0.0281 - val_accuracy: 0.9927
# Epoch 29/50
# 175/175 [==============================] - 4s 25ms/step - loss: 0.0189 - accuracy: 0.9934 - val_loss: 0.0352 - val_accuracy: 0.9871
# Epoch 30/50
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0096 - accuracy: 0.9962 - val_loss: 0.0265 - val_accuracy: 0.9903
# Epoch 31/50
# 175/175 [==============================] - 4s 25ms/step - loss: 0.0043 - accuracy: 0.9980 - val_loss: 0.0272 - val_accuracy: 0.9935
# Epoch 32/50
# 175/175 [==============================] - 4s 25ms/step - loss: 0.0043 - accuracy: 0.9983 - val_loss: 0.0236 - val_accuracy: 0.9903
# Epoch 33/50
# 175/175 [==============================] - 4s 25ms/step - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.0237 - val_accuracy: 0.9887
# Epoch 00033: early stopping
# INFO:tensorflow:Assets written to: edgisoftmaxtest1309.model\assets
